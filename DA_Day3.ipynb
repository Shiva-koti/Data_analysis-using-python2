# %% [markdown]
# pandas:
# * used for data manipulation(Data cleaning,OrganiZing data)
# * creates dataframes from excel,csv,txt,DBs
# * Dataframes(rows and columns read by python)
# * data clening by dropping and replacing with mean
# * visualize the data

# %%
import pandas as pd

# %%
names=["jwalitha","veena","shiva","ganesh","vamsi"]
index=[20,21,22,23,24]
ser1=pd.Series(names,index)
print(ser1)
# Out:
# 20    jwalitha
# 21       veena
# 22       shiva
# 23      ganesh
# 24       vamsi
# dtype: object

# %% [markdown]
# importing files
# * for csv and txt:read_csv("file path")
# * for excel:read_excel("file path")

# %%
df=pd.read_csv("/content/census2011.csv")
df.head(20)
# Out:
#     Ranking                    District           State  Population   Growth  \
# 0         1                       Thane     Maharashtra  11,060,148  36.01 %
# 1         2  North Twenty Four Parganas     West Bengal  10,009,781  12.04 %
# 2         3                   Bangalore       Karnataka   9,621,551  47.18 %
# 3         4                        Pune     Maharashtra   9,429,408  30.37 %
# 4         5             Mumbai Suburban     Maharashtra   9,356,962   8.29 %
# 5         6  South Twenty Four Parganas     West Bengal   8,161,961  18.17 %
# 6         7                  Barddhaman     West Bengal   7,717,563  11.92 %
# 7         8                   Ahmadabad         Gujarat   7,214,225  24.03 %
# 8         9                 Murshidabad     West Bengal   7,103,807  21.09 %
# 9        10                      Jaipur       Rajasthan   6,626,178  26.19 %
# 10       11                      Nashik     Maharashtra   6,107,187  22.30 %
# ...

# %%
dg=pd.read_excel("/content/census2011.xlsx")
print(dg.columns)
# Out:
# Index(['Ranking', 'District', 'State', 'Population', 'Growth', 'Sex-Ratio',
#        'Literacy'],
#       dtype='object')

# %%
dt=pd.read_csv("/content/Marvels (1).txt",sep=" ")
print(dt.describe)
# Out:
# <bound method NDFrame.describe of                                Movie\tRelease  \
# 0                                        Iron
# 1                                         The
# 2                                        Iron
# 3      Thor\t05-06-2011\tMay\t6\t2011\tMarvel
# 4                                     Captain
# ..                                        ...
# 61                                  Punisher:
# 62    Blade\t8/21/1998\tAugust\t21\t1998\tNew
# 63                                      Blade
# 64                                     Blade:
# 65  Morbius\t04-01-2022\tApril\t1\t2022\tSony
#
#                                         Date\tRelease  \
# 0               Man\t05-02-2008\tMay\t2\t2008\tMarvel
# 1                                          Incredible
# 2                                                 Man
# 3   Studios\t181030624\t240384926\t268295994\t3562...
# 4                                            America:
# ...

# %%
dt=pd.read_csv("/content/Marvels (1).txt",sep=" ")
print(dt.shape) #getting the number of rows and columns
print(dt.shape[0]) # getting the number of rows
print(dt.shape[1]) # getting the number of columns
# Out:
# (66, 31)
# 66
# 31

# %% [markdown]
# Accessing Data
# * loc-accepts column names and index
# * iloc-accepts only index

# %%
print(dg[2:5])
# Out:
#    Ranking         District        State Population   Growth  Sex-Ratio  \
# 2        3        Bangalore    Karnataka  9,621,551  47.18 %        916
# 3        4             Pune  Maharashtra  9,429,408  30.37 %        915
# 4        5  Mumbai Suburban  Maharashtra  9,356,962   8.29 %        860
#
#    Literacy
# 2     87.67
# 3     86.15
# 4     89.91

# %%
print(dg.loc[2:5,"District"])
# Out:
# 2                     Bangalore
# 3                          Pune
# 4               Mumbai Suburban
# 5    South Twenty Four Parganas
# Name: District, dtype: object

# %%
bts=pd.read_csv("/content/grades_withnulls.csv")
bts.head(10)
# Out:
#     Names Initials  SEM1  SEM2  SEM3 Grade  Placed
# 0     Joe        K   9.8  10.0   9.9    A+       1
# 1  Rajesh        M   8.9   9.1   9.3     A       1
# 2  Kissan        V   9.9   9.8  10.0     A       0
# 3    Mary        N   7.7   8.0   NaN     B       0
# 4    Jeen        K   9.8   9.1   9.9    A+       1
# 5     Raj        M   8.9   9.1   9.3     A       1
# 6  Hassan        V   9.9   9.0   9.2     A       1
# 7    Mari        N   7.7   8.0   7.1     B       1
# 8    Jess        K   NaN   9.1   9.9    A+       1
# 9  Rajini        M   NaN   9.1   9.3     A       0

# %%
bts.isnull()
# Out:
#     Names  Initials   SEM1   SEM2   SEM3  Grade  Placed
# 0   False     False  False  False  False  False   False
# 1   False     False  False  False  False  False   False
# 2   False     False  False  False  False  False   False
# 3   False     False  False  False   True  False   False
# 4   False     False  False  False  False  False   False
# 5   False     False  False  False  False  False   False
# 6   False     False  False  False  False  False   False
# 7   False     False  False  False  False  False   False
# 8   False     False   True  False  False  False   False
# 9   False     False   True  False  False  False   False
# 10  False     False   True  False  False  False   False
# 11  False     False  False  False  False  False   False
# 12  False     False  False  False  False  False   False
# 13  False     False  False  False  False  False   False
# 14  False     False  False  False  False  False   False
# 15  False     False  False  False  False  False   False
# ...

# %%
bts.isnull().sum()
# Out:
# Names       0
# Initials    0
# SEM1        3
# SEM2        0
# SEM3        1
# Grade       0
# Placed      0
# dtype: int64

# %%
bts.isnull().sum().sum()
# Out:
# 4

# %%
bts.dropna()
# Out:
#      Names Initials  SEM1  SEM2  SEM3 Grade  Placed
# 0      Joe        K   9.8  10.0   9.9    A+       1
# 1   Rajesh        M   8.9   9.1   9.3     A       1
# 2   Kissan        V   9.9   9.8  10.0     A       0
# 4     Jeen        K   9.8   9.1   9.9    A+       1
# 5      Raj        M   8.9   9.1   9.3     A       1
# 6   Hassan        V   9.9   9.0   9.2     A       1
# 7     Mari        N   7.7   8.0   7.1     B       1
# 11    Maya        N   7.7   8.0   7.1     B       0
# 12   Jolin        K   9.8   9.1   9.9    A+       1
# 13  Rajesh        M   8.9   9.1   9.3     A       1
# 14    Riya        M   9.3   9.9  10.0     A       1
# 15    Sana        V   9.9   9.3   9.2     A       0
# 16    Mark        N   7.7   8.0   7.0     B       0

# %%
btn=bts.dropna()

# %%
btn
# Out:
#      Names Initials  SEM1  SEM2  SEM3 Grade  Placed
# 0      Joe        K   9.8  10.0   9.9    A+       1
# 1   Rajesh        M   8.9   9.1   9.3     A       1
# 2   Kissan        V   9.9   9.8  10.0     A       0
# 4     Jeen        K   9.8   9.1   9.9    A+       1
# 5      Raj        M   8.9   9.1   9.3     A       1
# 6   Hassan        V   9.9   9.0   9.2     A       1
# 7     Mari        N   7.7   8.0   7.1     B       1
# 11    Maya        N   7.7   8.0   7.1     B       0
# 12   Jolin        K   9.8   9.1   9.9    A+       1
# 13  Rajesh        M   8.9   9.1   9.3     A       1
# 14    Riya        M   9.3   9.9  10.0     A       1
# 15    Sana        V   9.9   9.3   9.2     A       0
# 16    Mark        N   7.7   8.0   7.0     B       0

# %%
bts.fillna(1)
# Out:
#      Names Initials  SEM1  SEM2  SEM3 Grade  Placed
# 0      Joe        K   9.8  10.0   9.9    A+       1
# 1   Rajesh        M   8.9   9.1   9.3     A       1
# 2   Kissan        V   9.9   9.8  10.0     A       0
# 3     Mary        N   7.7   8.0   1.0     B       0
# 4     Jeen        K   9.8   9.1   9.9    A+       1
# 5      Raj        M   8.9   9.1   9.3     A       1
# 6   Hassan        V   9.9   9.0   9.2     A       1
# 7     Mari        N   7.7   8.0   7.1     B       1
# 8     Jess        K   1.0   9.1   9.9    A+       1
# 9   Rajini        M   1.0   9.1   9.3     A       0
# 10   Kiran        V   1.0   9.3   9.2     A       0
# 11    Maya        N   7.7   8.0   7.1     B       0
# 12   Jolin        K   9.8   9.1   9.9    A+       1
# 13  Rajesh        M   8.9   9.1   9.3     A       1
# 14    Riya        M   9.3   9.9  10.0     A       1
# 15    Sana        V   9.9   9.3   9.2     A       0
# 16    Mark        N   7.7   8.0   7.0     B       0

# %% [markdown]
# cleaning with mean

# %%
m=bts['SEM1'].mean()
print(m)
# Out:
# 8.992857142857144

# %%
bts2=bts.fillna(m)
print(bts2)
# Out:
#      Names Initials      SEM1  SEM2       SEM3 Grade  Placed
# 0      Joe        K  9.800000  10.0   9.900000    A+       1
# 1   Rajesh        M  8.900000   9.1   9.300000     A       1
# 2   Kissan        V  9.900000   9.8  10.000000     A       0
# 3     Mary        N  7.700000   8.0   8.992857     B       0
# 4     Jeen        K  9.800000   9.1   9.900000    A+       1
# 5      Raj        M  8.900000   9.1   9.300000     A       1
# 6   Hassan        V  9.900000   9.0   9.200000     A       1
# 7     Mari        N  7.700000   8.0   7.100000     B       1
# 8     Jess        K  8.992857   9.1   9.900000    A+       1
# 9   Rajini        M  8.992857   9.1   9.300000     A       0
# 10   Kiran        V  8.992857   9.3   9.200000     A       0
# 11    Maya        N  7.700000   8.0   7.100000     B       0
# 12   Jolin        K  9.800000   9.1   9.900000    A+       1
# 13  Rajesh        M  8.900000   9.1   9.300000     A       1
# ...

# %%
bts2.drop_duplicates()
# Out:
#      Names Initials      SEM1  SEM2       SEM3 Grade  Placed
# 0      Joe        K  9.800000  10.0   9.900000    A+       1
# 1   Rajesh        M  8.900000   9.1   9.300000     A       1
# 2   Kissan        V  9.900000   9.8  10.000000     A       0
# 3     Mary        N  7.700000   8.0   8.992857     B       0
# 4     Jeen        K  9.800000   9.1   9.900000    A+       1
# 5      Raj        M  8.900000   9.1   9.300000     A       1
# 6   Hassan        V  9.900000   9.0   9.200000     A       1
# 7     Mari        N  7.700000   8.0   7.100000     B       1
# 8     Jess        K  8.992857   9.1   9.900000    A+       1
# 9   Rajini        M  8.992857   9.1   9.300000     A       0
# 10   Kiran        V  8.992857   9.3   9.200000     A       0
# 11    Maya        N  7.700000   8.0   7.100000     B       0
# 12   Jolin        K  9.800000   9.1   9.900000    A+       1
# 14    Riya        M  9.300000   9.9  10.000000     A       1
# ...

# %%
bts2.rename(columns={"Grade":"GPA"},inplace=True) #df.rename(columns={old:new})
bts2.head()
# Out:
#     Names Initials  SEM1  SEM2       SEM3 GPA  Placed  Avg_score
# 0     Joe        K   9.8  10.0   9.900000  A+       1   9.900000
# 1  Rajesh        M   8.9   9.1   9.300000   A       1   9.100000
# 2  Kissan        V   9.9   9.8  10.000000   A       0   9.900000
# 3    Mary        N   7.7   8.0   8.992857   B       0   8.230952
# 4    Jeen        K   9.8   9.1   9.900000  A+       1   9.600000

# %%
print(bts)
# Out:
#      Names Initials  SEM1  SEM2  SEM3 Grade  Placed
# 0      Joe        K   9.8  10.0   9.9    A+       1
# 1   Rajesh        M   8.9   9.1   9.3     A       1
# 2   Kissan        V   9.9   9.8  10.0     A       0
# 3     Mary        N   7.7   8.0   NaN     B       0
# 4     Jeen        K   9.8   9.1   9.9    A+       1
# 5      Raj        M   8.9   9.1   9.3     A       1
# 6   Hassan        V   9.9   9.0   9.2     A       1
# 7     Mari        N   7.7   8.0   7.1     B       1
# 8     Jess        K   NaN   9.1   9.9    A+       1
# 9   Rajini        M   NaN   9.1   9.3     A       0
# 10   Kiran        V   NaN   9.3   9.2     A       0
# 11    Maya        N   7.7   8.0   7.1     B       0
# 12   Jolin        K   9.8   9.1   9.9    A+       1
# 13  Rajesh        M   8.9   9.1   9.3     A       1
# 14    Riya        M   9.3   9.9  10.0     A       1
# 15    Sana        V   9.9   9.3   9.2     A       0
# 16    Mark        N   7.7   8.0   7.0     B       0

# %%
bts2['Avg_score']=(bts2['SEM1']+bts2['SEM2']+bts2['SEM3'])/3
bts2.head()
# Out:
#     Names Initials  SEM1  SEM2       SEM3 GPA  Placed  Avg_score
# 0     Joe        K   9.8  10.0   9.900000  A+       1   9.900000
# 1  Rajesh        M   8.9   9.1   9.300000   A       1   9.100000
# 2  Kissan        V   9.9   9.8  10.000000   A       0   9.900000
# 3    Mary        N   7.7   8.0   8.992857   B       0   8.230952
# 4    Jeen        K   9.8   9.1   9.900000  A+       1   9.600000

# %%
bts2[['SEM1','SEM2']].plot.line()
# Out:
# <Axes: >

# %%
bts2.plot.line(subplots=True)
# Out:
# array([<Axes: >, <Axes: >, <Axes: >, <Axes: >, <Axes: >], dtype=object)

# %%
import seaborn as sns

# %%
pl=sns.lineplot(x="Initials",y='SEM1',data=bts2)

# %%
sns.relplot(data=bts2,x="SEM2",y='SEM1')

# %%
sns.relplot(data=bts2,x="SEM2",y='SEM1',col='Placed')

# %% [markdown]
# load diabites
# create a relplot
# with age in x-axis and class as columns

# %%
sns.relplot(data=bts2,x="SEM2",y='SEM1')

# %%
sns.relplot(data=bts2,x="SEM2",y='SEM1',col='Placed')

# %%
import pandas as pd
ab=pd.read_csv("/content/diabetcsv (5).csv")
ab
# Out:
#      preg  plas  pres  skin  insu  mass   pedi  age            class
# 0       6   148    72    35     0  33.6  0.627   50  tested_positive
# 1       1    85    66    29     0  26.6  0.351   31  tested_negative
# 2       8   183    64     0     0  23.3  0.672   32  tested_positive
# 3       1    89    66    23    94  28.1  0.167   21  tested_negative
# 4       0   137    40    35   168  43.1  2.288   33  tested_positive
# ..    ...   ...   ...   ...   ...   ...    ...  ...              ...
# 763    10   101    76    48   180  32.9  0.171   63  tested_negative
# 764     2   122    70    27     0  36.8  0.340   27  tested_negative
# 765     5   121    72    23   112  26.2  0.245   30  tested_negative
# 766     1   126    60     0     0  30.1  0.349   47  tested_positive
# 767     1    93    70    31     0  30.4  0.315   23  tested_negative
#
# [768 rows x 9 columns]

# %%
import pandas as pd
ak=pd.read_csv('/content/household_power_consumption.csv')
xe=ak.head()

# %%
xe
# Out:
#    index    Date     Time Global_active_power Global_reactive_power Voltage  \
# 0      0  1/1/07  0:00:00                2.58                 0.136  241.97
# 1      1  1/1/07  0:01:00               2.552                   0.1  241.75
# 2      2  1/1/07  0:02:00                2.55                   0.1  241.64
# 3      3  1/1/07  0:03:00                2.55                   0.1  241.71
# 4      4  1/1/07  0:04:00               2.554                   0.1  241.98
#
#   Global_intensity Sub_metering_1 Sub_metering_2  Sub_metering_3
# 0             10.6              0              0             0.0
# 1             10.4              0              0             0.0
# 2             10.4              0              0             0.0
# 3             10.4              0              0             0.0
# 4             10.4              0              0             0.0

# %%
import seaborn as sns
ab['Index']=range(1,769)
sns.relplot(data=ab,x='Index',y='age',col="class")

# %% [markdown]
# # inbuilt data sets
# to load data sets-load_dataset("dataset name")
# - tips
# - dowjones
# - fmri
# - dots
# - health app
# - seaborn
# - pandas
# - color palettes-pastel,bright,dark,muted,color_blind
# - list item

# %%
tips=sns.load_dataset("tips")
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.relplot(data=tips,x='total_bill',y='tip',col="sex")

# %%
sns.lineplot(data=tips,x='total_bill',y='tip')
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
sns.relplot(data=tips,x='total_bill',y='tip',hue='smoker')

# %%
sns.relplot(data=tips,x='total_bill',y='tip',hue='time')

# %%
sns.relplot(data=tips,x='total_bill',y='tip',hue='day')

# %%
sns.relplot(data=tips,x='total_bill',y='tip',hue='smoker',style='time')

# %%
sns.relplot(data=tips,x='total_bill',y='tip',hue='smoker',style='day')

# %%
sns.relplot(data=tips,x='total_bill',y='tip',hue='smoker',style='time',palette='pastel')

# %%
dowjones=sns.load_dataset("dowjones")
dowjones.head()
# Out:
#         Date  Price
# 0 1914-12-01  55.00
# 1 1915-01-01  56.55
# 2 1915-02-01  56.00
# 3 1915-03-01  58.30
# 4 1915-04-01  66.45

# %%
sns.relplot(data=dowjones,x='Date',y='Price',kind='line')

# %%
fmri=sns.load_dataset("fmri")
fmri.head()
# Out:
#   subject  timepoint event    region    signal
# 0     s13         18  stim  parietal -0.017552
# 1      s5         14  stim  parietal -0.080883
# 2     s12         18  stim  parietal -0.081033
# 3     s11         18  stim  parietal -0.046134
# 4     s10         18  stim  parietal -0.037970

# %%
sns.relplot(data=fmri,x='timepoint',y='signal',kind='line')

# %%
sns.catplot(data=tips,x='total_bill',y='day')

# %%
sns.catplot(data=fmri,x='timepoint',y='signal')

# %%
sns.catplot(data=tips,x='total_bill',y='day',kind='violin',hue='smoker')

# %% [markdown]
# linearfit-implot()
# - plotting the data
# - fitting the line
# - predicting the line

# %%
sns.lmplot(x="size",y="tip",data=tips)

# %%
import pandas as pd

# %%
dr=pd.read_csv("/content/diabetcsv (5).csv")
first_row=dr.loc[1:1]
first_row.head()
# Out:
#    preg  plas  pres  skin  insu  mass   pedi  age            class
# 1     1    85    66    29     0  26.6  0.351   31  tested_negative
