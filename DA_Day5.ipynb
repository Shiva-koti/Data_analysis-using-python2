# %%
import requests

# %%
page=requests.get('https://randomfox.ca/floof')

# %%
print(page.status_code)
# Out:
# 200

# %%
print(page.text)
# Out:
# {"image":"https:\/\/randomfox.ca\/images\/2.jpg","link":"https:\/\/randomfox.ca\/?i=2"}

# %%
#This example uses Python 2.7 and the python-request library.

from requests import Request, Session
from requests.exceptions import ConnectionError, Timeout, TooManyRedirects
import json

url = 'https://sandbox-api.coinmarketcap.com/v1/cryptocurrency/listings/latest'
parameters = {
  'start':'1',
  'limit':'5000',
  'convert':'USD'
}
headers = {
  'Accepts': 'application/json',
  'X-CMC_PRO_API_KEY': '8242b487-fe32-4dcb-8ff4-6fbad546394e',
}

session = Session()
session.headers.update(headers)

try:
  response = session.get(url, params=parameters)
  data = json.loads(response.text)
  print(data)
except (ConnectionError, Timeout, TooManyRedirects) as e:
  print(e)
# Out:
# {'status': {'timestamp': '2024-02-16T10:08:09.622Z', 'error_code': 0, 'error_message': None, 'elapsed': 1, 'credit_count': 1, 'notice': None}, 'data': [{'id': 5168, 'name': 'nj2yb7ml4ur', 'symbol': 'bzfxqsocx5f', 'slug': '5x7h0qt0f34', 'cmc_rank': 1064, 'num_market_pairs': 5297, 'circulating_supply': 481, 'total_supply': 4695, 'max_supply': 8296, 'infinite_supply': None, 'last_updated': '2024-02-16T10:08:09.622Z', 'date_added': '2024-02-16T10:08:09.622Z', 'tags': ['sic43svhxb', '8d3nk374djq', 'igjfnzh4fhe', 'w9ucrsk463', 'dy5smkgkem7', 'omuuz5u6nwn', '4dgmbx20wtj', 'h2n4liihsqu', 'ie3hdu2gtji', 'gk3luihukj'], 'platform': None, 'self_reported_circulating_supply': None, 'self_reported_market_cap': None, 'quote': {'USD': {'price': 0.6229943521533103, 'volume_24h': 5052, 'volume_change_24h': 0.0400409793601646, 'percent_change_1h': 0.1273505294444286, 'percent_change_24h': 0.3184847213888766, 'percent_change_7d': 0.48863685690829417, 'market_cap': 0.7420107803391545, 'market_cap_dominanc
# ...

# %%
import pandas as pd
norm=pd.json_normalize(data['data'])
norm
# Out:
#      id         name        symbol         slug  cmc_rank  num_market_pairs  \
# 0  5168  nj2yb7ml4ur   bzfxqsocx5f  5x7h0qt0f34      1064              5297
# 1  1380  b32i8z3nxqg   pzz63zkobp8  ionr4vx7rie       310              9579
# 2  9255  uafvqgxqg9g   18gimka7j9s  exvkkl77qgc       205              2280
# 3  9711  svy24x616uj   3vmpxsyv9za  8okk2sse4c3      2358              5512
# 4  5100  x3x9sugcous    z2nkdcu4mo  dlom2o2fzx7      3191               732
# 5  2391  uzieohsnmwj  1xg8ax4cje1i  qxssgxb8k3f      2799              2204
# 6  8157  4m1lqpn0yx5   e0bgowle2is  f76l2ieelnb      1345               618
# 7  9545  gaxrf8mbufe   2qppt5km8qk  1q8g96v7rjn      4291               218
# 8   357  6g6teg96nym   pybau2ohx89   bui5l1lqbj      7409              7100
# 9  7768  651hr3q5oji    fu98a73k3i  3160fmd4jq4      1749              5722
#
#    circulating_supply  total_supply  max_supply infinite_supply  ...  \
# ...

# %% [markdown]
# Extracting data from CoinMarket cap API:
#
# program Flow:
# - Go to Coinmarket cap website
# - Go to product-->API and obtain API key
# - Go to documentation to obtain API code!
# - Know your code!
# - Run it in any python environment
# - Obtain data in the form of json
# - Normalize the data into a dataframe
# - Save it if you needed

# %% [markdown]
# Machine learning
#
# - Like humans learn from their past experiences,machine learn from past data!
# - Training a machine on various things

# %% [markdown]
# Types of machine learning
#
# - Supervised learning
# - unsupervised learning
# - reinforcement
#
# supervised learning
# -learns a function that maps an input to a desired output,based on labeled training data.think of it like a student learning from a teacher who provides solutions to problems
# - ex:assume the learning a machine about 3 different coins labels rupee,dhirams,euros
# - features:By weight as its feature and find the coin by its weight 3,7,4 grams
# - Input:labelled data giving a feature
# - output:selecting one by its lable by given weight
# - prediction:when i provide a new coin it ask the weight if the
